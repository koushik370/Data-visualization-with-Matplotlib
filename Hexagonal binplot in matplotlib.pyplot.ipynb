# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(size=(1,500))
y=np.random.normal(size=(1,500))
plt.hexbin(x,y,gridsize=5,mincnt=1,edgecolor="red",cmap="inferno")
plt.title("hexagonal binplot",color="green")
plt.xlabel("X_vlaues")
plt.ylabel("Y_values")
plt.show()
