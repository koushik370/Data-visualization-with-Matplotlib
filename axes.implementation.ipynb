# %%
import matplotlib.pyplot as plt
x=[1,2,3,3,5]
y=[3,2,4,5,3]
fig=plt.figure()
left,bottom,width,height=0.2,0.3,0.6,0.6
ax=fig.add_axes([left,bottom,width,height])
ax.plot(x,y)
plt.grid()
plt.show()
