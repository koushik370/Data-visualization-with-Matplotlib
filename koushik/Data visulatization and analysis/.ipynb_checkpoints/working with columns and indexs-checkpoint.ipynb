# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Admin\Desktop\excelfiles\Book1.csv")

# %%
data.head(2)
# Out:
#    Film                       Genre Lead Studio       Audience score %  \
# 0   NaN  Zack and Miri Make a Porno     Romance  The Weinstein Company
# 1   NaN             Youth in Revolt      Comedy  The Weinstein Company
#
#    Profitability  Rotten Tomatoes %  Worldwide Gross    Year  Unnamed: 8
# 0             70           1.747542               64  $41.94        2008
# 1             52           1.090000               68  $19.62        2010

# %%
index=data.set_index("Genre")

# %%
index
# Out:
#                                     Film Lead Studio       Audience score %  \
# Genre
# Zack and Miri Make a Porno           NaN     Romance  The Weinstein Company
# Youth in Revolt                      NaN      Comedy  The Weinstein Company
# You Will Meet a Tall Dark Stranger   NaN      Comedy            Independent
# When in Rome                         NaN      Comedy                 Disney
# What Happens in Vegas                NaN      Comedy                    Fox
# ...                                  ...         ...                    ...
# Across the Universe                  NaN     romance            Independent
# A Serious Man                        NaN       Drama              Universal
# A Dangerous Method                   NaN       Drama            Independent
# 27 Dresses                           NaN      Comedy                    Fox
# (500) Days of Summer                 NaN      comedy                    Fox
#
# ...

# %%
index_map={"Zack and Miri Make a Porno":"Dhamaka",
          "Youth in Revolt":"uppena",
          "You Will Meet a Tall Dark Stranger":"salar",
          "When in Rome":"adhipursh"}
col_map={"Genre":"Movies name",
        "Lead Studio":"Gonor",
"Rotten Tomatoes %":"rating",
        "Audience score %":"Production"}

# %%
temp_1=index.rename(columns=col_map,index=index_map).assign(status="hit").head(4)
temp_1
# Out:
#            Film    Gonor             Production  Profitability    rating  \
# Genre
# Dhamaka     NaN  Romance  The Weinstein Company             70  1.747542
# uppena      NaN   Comedy  The Weinstein Company             52  1.090000
# salar       NaN   Comedy            Independent             35  1.211818
# adhipursh   NaN   Comedy                 Disney             44  0.000000
#
#            Worldwide Gross    Year  Unnamed: 8 status
# Genre
# Dhamaka                 64  $41.94        2008    hit
# uppena                  68  $19.62        2010    hit
# salar                   43  $26.66        2010    hit
# adhipursh               15  $43.04        2010    hit

# %%
index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77 entries, Zack and Miri Make a Porno to (500) Days of Summer
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               0 non-null      float64
#  1   Lead Studio        77 non-null     object
#  2   Audience score %   77 non-null     object
#  3   Profitability      77 non-null     int64
#  4   Rotten Tomatoes %  77 non-null     float64
#  5   Worldwide Gross    77 non-null     int64
#  6   Year               77 non-null     object
#  7   Unnamed: 8         77 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 7.5+ KB

# %%
total=( temp_1["Profitability"]+
       temp_1["Worldwide Gross"]
       )
total
# Out:
# Genre
# Dhamaka      134
# uppena       120
# salar         78
# adhipursh     59
# dtype: int64

# %%
status_result=temp_1.assign(total_gross=total)
status_result
# Out:
#            Film    Gonor             Production  Profitability    rating  \
# Genre
# Dhamaka     NaN  Romance  The Weinstein Company             70  1.747542
# uppena      NaN   Comedy  The Weinstein Company             52  1.090000
# salar       NaN   Comedy            Independent             35  1.211818
# adhipursh   NaN   Comedy                 Disney             44  0.000000
#
#            Worldwide Gross    Year  Unnamed: 8 status  total_gross
# Genre
# Dhamaka                 64  $41.94        2008    hit          134
# uppena                  68  $19.62        2010    hit          120
# salar                   43  $26.66        2010    hit           78
# adhipursh               15  $43.04        2010    hit           59

# %%
##this method is used to sum the columns and return the values
cols=["Profitability","Worldwide Gross"]
sum_col=temp_1.loc[:,cols].sum(axis="columns")

# %%
sum_col.head(4)
# Out:
# Genre
# Dhamaka      134
# uppena       120
# salar         78
# adhipursh     59
# dtype: int64

# %%
cols=(temp_1["Profitability"]+
        temp_1["Worldwide Gross"])
cols
# Out:
# Genre
# Dhamaka      134
# uppena       120
# salar         78
# adhipursh     59
# dtype: int64

# %%
##idnetifying the missing values
##checking the cout of missing value
##if it don't find any missing values it result sum as 0
status_result.assign(total_lines="Film")["total_lines"].isna().sum()
# Out:
# 0

# %%
status_result.assign(total_likes=total)["total_likes"].isna()
# Out:
# Genre
# Dhamaka      False
# uppena       False
# salar        False
# adhipursh    False
# Name: total_likes, dtype: bool

# %%
status_result
# Out:
#            Film    Gonor             Production  Profitability    rating  \
# Genre
# Dhamaka     NaN  Romance  The Weinstein Company             70  1.747542
# uppena      NaN   Comedy  The Weinstein Company             52  1.090000
# salar       NaN   Comedy            Independent             35  1.211818
# adhipursh   NaN   Comedy                 Disney             44  0.000000
#
#            Worldwide Gross    Year  Unnamed: 8  total_gross
# Genre
# Dhamaka                 64  $41.94        2008          134
# uppena                  68  $19.62        2010          120
# salar                   43  $26.66        2010           78
# adhipursh               15  $43.04        2010           59

# %%
##we can check the columns are greater than each other by creating a funtion 
##and selcting the columns and assinging them to new funtion

def cast_get_actor(df):
     return(
          df["total_gross"]>=df["total"])
df2=status_result.assign(total=total,total_gross=cast_get_actor)
df2
# Out:
#            Film    Gonor             Production  Profitability    rating  \
# Genre
# Dhamaka     NaN  Romance  The Weinstein Company             70  1.747542
# uppena      NaN   Comedy  The Weinstein Company             52  1.090000
# salar       NaN   Comedy            Independent             35  1.211818
# adhipursh   NaN   Comedy                 Disney             44  0.000000
#
#            Worldwide Gross    Year  Unnamed: 8 status  total_gross  total
# Genre
# Dhamaka                 64  $41.94        2008    hit         True    134
# uppena                  68  $19.62        2010    hit         True    120
# salar                   43  $26.66        2010    hit         True     78
# adhipursh               15  $43.04        2010    hit         True     59

# %%
status_result.total_gross
# Out:
# Genre
# Dhamaka      134
# uppena       120
# salar         78
# adhipursh     59
# Name: total_gross, dtype: int64

# %%
##drop method is used to delete the column which you selected
status_result=status_result.drop(columns='Production')

# %%
status_result
# Out:
#            Film    Gonor  Profitability    rating  Worldwide Gross    Year  \
# Genre
# Dhamaka     NaN  Romance             70  1.747542               64  $41.94
# uppena      NaN   Comedy             52  1.090000               68  $19.62
# salar       NaN   Comedy             35  1.211818               43  $26.66
# adhipursh   NaN   Comedy             44  0.000000               15  $43.04
#
#            Unnamed: 8  total_gross
# Genre
# Dhamaka          2008          134
# uppena           2010          120
# salar            2010           78
# adhipursh        2010           59

# %%
colu={"Unnamed: 8":"Award Year"} ##we can change the column name by applying modification funtion

# %%
status_result=status_result.rename(columns=colu)
status_result
# Out:
#            Film    Gonor  Profitability    rating  Worldwide Gross    Year  \
# Genre
# Dhamaka     NaN  Romance             70  1.747542               64  $41.94
# uppena      NaN   Comedy             52  1.090000               68  $19.62
# salar       NaN   Comedy             35  1.211818               43  $26.66
# adhipursh   NaN   Comedy             44  0.000000               15  $43.04
#
#            Award Year  total_gross
# Genre
# Dhamaka          2008          134
# uppena           2010          120
# salar            2010           78
# adhipursh        2010           59

# %%
status_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Dhamaka to adhipursh
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             0 non-null      float64
#  1   Gonor            4 non-null      object
#  2   Profitability    4 non-null      int64
#  3   rating           4 non-null      float64
#  4   Worldwide Gross  4 non-null      int64
#  5   Year             4 non-null      object
#  6   Award Year       4 non-null      int64
#  7   total_gross      4 non-null      int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 460.0+ bytes

# %%
##for combining inthe columns
for i in status_result.columns:
     if "Year" in i and "Award Year" in i:
            print(i)
# Out:
# Award Year

# %%
##we can also add or insert column into particular location by using insert method
location=status_result.columns.get_loc("Year")+1 ##this method is used to find the location of the particular column
location
# Out:
# 6

# %%
status_result
# Out:
#            Film    Gonor  Profitability    rating  Worldwide Gross    Year  \
# Genre
# Dhamaka     NaN  Romance             70  1.747542               64  $41.94
# uppena      NaN   Comedy             52  1.090000               68  $19.62
# salar       NaN   Comedy             35  1.211818               43  $26.66
# adhipursh   NaN   Comedy             44  0.000000               15  $43.04
#
#            Award Year  total_gross
# Genre
# Dhamaka          2008          134
# uppena           2010          120
# salar            2010           78
# adhipursh        2010           59

# %%
status_result.insert(loc=location,column="profit",value=status_result["Profitability"]-status_result["total_gross"])

# %%
status_result
# Out:
#            Film    Gonor  Profitability    rating  Worldwide Gross    Year  \
# Genre
# Dhamaka     NaN  Romance             70  1.747542               64  $41.94
# uppena      NaN   Comedy             52  1.090000               68  $19.62
# salar       NaN   Comedy             35  1.211818               43  $26.66
# adhipursh   NaN   Comedy             44  0.000000               15  $43.04
#
#            profit  Award Year  total_gross
# Genre
# Dhamaka       -64        2008          134
# uppena        -68        2010          120
# salar         -43        2010           78
# adhipursh     -15        2010           59
