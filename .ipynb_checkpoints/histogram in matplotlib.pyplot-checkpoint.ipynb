# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.random.rand(1000)
plt.hist(y,bins=50,edgecolor="k",color="pink")
plt.xlabel("count")
plt.title("Histogram in matplotlib",color="red",style="oblique",weight="bold")
plt.show()
