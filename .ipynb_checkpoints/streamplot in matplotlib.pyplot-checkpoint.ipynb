# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,10)
y=np.arange(0,10)
X,Y=np.meshgrid(x,y)
u=np.ones((10,10))
v=np.zeros((10,10))
plt.streamplot(X,Y,u,v,density=0.5)
plt.title("stream plot of parallel lines",color="red",size=16)
plt.show()
