# %%
import matplotlib.pyplot as plt
import numpy as np
N=150
radius=np.random.rand(N)
theta=2*np.pi*np.random.rand(N)
size=radius*100
plt.subplot(projection="polar")
plt.scatter(theta,radius,c=theta,cmap="hsv",s=size,alpha=0.5)
plt.show()
