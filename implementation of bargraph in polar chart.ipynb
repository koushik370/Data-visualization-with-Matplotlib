# %%
import matplotlib.pyplot as plt
import numpy as np
N=10
theta=np.linspace(0.0,2*np.pi,N)
r=10*np.random.rand(N)
plt.subplot(projection="polar")
plt.bar(theta,r,bottom=0.0,color=["r","g","b"],alpha=0.8)
plt.show()
